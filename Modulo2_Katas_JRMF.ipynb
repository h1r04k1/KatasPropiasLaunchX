# %% [markdown]
# # Crear y Administrar paquetes

# %% [markdown]
# ->> win + r
#
# ->> escribir  cmd en el textfield
#
# ->> escribir la direccion donde se va almacenar los proyectos de entorno virtual de python
#
#     Microsoft Windows [Versión 10.0.19043.1526]
#     (c) Microsoft Corporation. Todos los derechos reservados.
#
#     C:\Users\h1r04>D:
#
#     D:\>mkdir D:\blackBox
#
#     D:\>cd blackBox
#
#     D:\blackBox>
#
# ->> Crear un entorno virtual de python
#
#     D:\blackBox>python -m venv naomi
#
# ->> revisar el contenido del directorio
#
#     D:\blackBox>dir naomi
#     El volumen de la unidad D es 5H4773RD0M3
#     El número de serie del volumen es: 0440-C93A
#
#     Directorio de D:\blackBox\naomi
#
#     14/02/2022  10:46 p. m.    <DIR>          .
#     14/02/2022  10:46 p. m.    <DIR>          ..
#     14/02/2022  10:46 p. m.    <DIR>          Include
#     14/02/2022  10:46 p. m.    <DIR>          Lib
#     14/02/2022  10:46 p. m.               117 pyvenv.cfg
#     14/02/2022  10:46 p. m.    <DIR>          Scripts
#                1 archivos            117 bytes
#                5 dirs  414,921,895,936 bytes libres
#
# ->> ir a la carpeta scrpts y activar el entorno virtual de python 3
#
#     D:\blackBox>cd naomi
#
#     D:\blackBox\naomi>cd Scripts
#
#     D:\blackBox\naomi\Scripts>activate
#
# ->> el simbolo de sistema cambia
#
#     (naomi) D:\blackBox\naomi\Scripts>
#
# ->> se puede comprobar la version de python, la version de pip y la ruta donde se encuentra
#
# (naomi) D:\blackBox\naomi\Scripts>python --version
# Python 3.9.1
#
# (naomi) D:\blackBox\naomi\Scripts>where python
# D:\blackBox\naomi\Scripts\python.exe
# C:\Users\h1r04\AppData\Local\Programs\Python\Python39\python.exe
# C:\Users\h1r04\AppData\Local\Microsoft\WindowsApps\python.exe
#
# (naomi) D:\blackBox\naomi\Scripts>pip -V
# pip 20.2.3 from d:\blackbox\naomi\lib\site-packages\pip (python 3.9)
#
# ->> instale unos cuantos paquetes
#
# (naomi) D:\blackBox\naomi\Scripts>pip install art
# Collecting art
#   Downloading art-5.4-py2.py3-none-any.whl (580 kB)
#      |████████████████████████████████| 580 kB 1.3 MB/s
# Installing collected packages: art
# Successfully installed art-5.4
# WARNING: You are using pip version 20.2.3; however, version 22.0.3 is available.
# You should consider upgrading via the 'd:\blackbox\naomi\scripts\python.exe -m pip install --upgrade pip' command.
#
#
# (naomi) D:\blackBox\naomi\Scripts>pip install python-dateutil
# Collecting python-dateutil
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting six>=1.5
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: six, python-dateutil
# Successfully installed python-dateutil-2.8.2 six-1.16.0
# WARNING: You are using pip version 20.2.3; however, version 22.0.3 is available.
# You should consider upgrading via the 'd:\blackbox\naomi\scripts\python.exe -m pip install --upgrade pip' command.
#
# ->> vemos los paquetes instalados
#
# (naomi) D:\blackBox\naomi\Scripts>pip freeze
# art==5.4
# python-dateutil==2.8.2
# six==1.16.0
#
#
# ->> ponemos a prueba el paquete que se instalo
#
# (naomi) D:\blackBox\naomi\Scripts>python
# Python 3.9.1 (tags/v3.9.1:1e5d33e, Dec  7 2020, 17:08:21) [MSC v.1927 64 bit (AMD64)] on win32
# Type "help", "copyright", "credits" or "license" for more information.
# >>> from art import *
# >>> Art=text2art("SALUDOS",font='block',chr_ignore=True)
# >>> print(Art)
#
#  .----------------.  .----------------.  .----------------.  .----------------.  .----------------.  .----------------.  .----------------.
# | .--------------. || .--------------. || .--------------. || .--------------. || .--------------. || .--------------. || .--------------. |
# | |    _______   | || |      __      | || |   _____      | || | _____  _____ | || |  ________    | || |     ____     | || |    _______   | |
# | |   /  ___  |  | || |     /  \     | || |  |_   _|     | || ||_   _||_   _|| || | |_   ___ `.  | || |   .'    `.   | || |   /  ___  |  | |
# | |  |  (__ \_|  | || |    / /\ \    | || |    | |       | || |  | |    | |  | || |   | |   `. \ | || |  /  .--.  \  | || |  |  (__ \_|  | |
# | |   '.___`-.   | || |   / ____ \   | || |    | |   _   | || |  | '    ' |  | || |   | |    | | | || |  | |    | |  | || |   '.___`-.   | |
# | |  |`\____) |  | || | _/ /    \ \_ | || |   _| |__/ |  | || |   \ `--' /   | || |  _| |___.' / | || |  \  `--'  /  | || |  |`\____) |  | |
# | |  |_______.'  | || ||____|  |____|| || |  |________|  | || |    `.__.'    | || | |________.'  | || |   `.____.'   | || |  |_______.'  | |
# | |              | || |              | || |              | || |              | || |              | || |              | || |              | |
# | '--------------' || '--------------' || '--------------' || '--------------' || '--------------' || '--------------' || '--------------' |
#  '----------------'  '----------------'  '----------------'  '----------------'  '----------------'  '----------------'  '----------------'
#
# >>> quit()
#
# (naomi) D:\blackBox\naomi\Scripts>
#
# ->> se desactiva el entorno virtual
#
# (naomi) D:\blackBox\naomi\Scripts>deactivate
# D:\blackBox\naomi\Scripts>
